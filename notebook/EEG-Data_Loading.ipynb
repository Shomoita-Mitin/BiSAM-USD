# %% [markdown]
# # 1. Data Loading and Raw data basic Information

# %%
import mne
import os
# %matplotlib qt
import numpy as np
# %ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 9A8D-5652
#
#  Directory of C:\Users\shomo\OneDrive\Desktop\BISAM-USD\notebook
#
# 09/20/2024  01:35 AM    <DIR>          .
# 09/20/2024  01:28 AM    <DIR>          ..
# 09/20/2024  01:35 AM    <DIR>          .ipynb_checkpoints
# 09/20/2024  01:35 AM                72 EEG-Data_Loading.ipynb
#                1 File(s)             72 bytes
#                3 Dir(s)  727,323,688,960 bytes free

# %%
vhdr_file = 'Control1001.vhdr'
raw = mne.io.read_raw_brainvision(vhdr_file, preload=True)
# Out:
# Extracting parameters from Control1001.vhdr...
# Setting channel info structure...
# C:\Users\shomo\AppData\Local\Temp\ipykernel_15616\1764153127.py:2: RuntimeWarning: Online software filter detected. Using software filter settings and ignoring hardware values
#   raw = mne.io.read_raw_brainvision(vhdr_file, preload=True)
# Reading 0 ... 134449  =      0.000 ...   268.898 secs...

# %%
print(raw.info)
# Out:
# <Info | 8 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, P3, P7, ...
#  chs: 63 EEG
#  custom_ref_applied: False
#  dig: 66 items (3 Cardinal, 63 EEG)
#  highpass: 0.0 Hz
#  lowpass: 250.0 Hz
#  meas_date: 2017-11-14 13:26:21 UTC
#  nchan: 63
#  projs: []
#  sfreq: 500.0 Hz
# >

# %% [markdown]
# # 2. Raw EEG Data Ploting

# %%
raw.plot()
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 800x800 with 4 Axes>
